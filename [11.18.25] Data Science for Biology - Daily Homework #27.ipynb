# %% [markdown]
# 1. One purpose of github to assists software developers to collaborate on software projects
# 2. Version controls lets developers maintain a history of their code, recording any changes that are made. This could be helpful for our porject as it would allow for us to review older versions of our code.
# 3. Github facilitates group coding by several people to simultaneously work on the same project by merging changes made by different authors back to the main project.
# 4. Employers can review a candidate's github site to see a real-life demonstration of coding skills that goes beyond what a resume could illustrate.
